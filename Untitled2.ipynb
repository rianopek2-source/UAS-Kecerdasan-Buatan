# %% [markdown]
# <a href="https://colab.research.google.com/github/rianopek2-source/UAS-Kecerdasan-Buatan/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt

# ==========================================
# 1. DATA INPUT & IDENTITAS RIAN (24146049)
# ==========================================
NIM_RIAN = "24146049"
random.seed(int(NIM_RIAN))  # Seed acak menggunakan NIM Rian

courses = [
    ("AI", "DosenA"), ("ML", "DosenB"), ("DB", "DosenC"),
    ("CN", "DosenD"), ("SE", "DosenE"), ("OS", "DosenF"),
    ("IR", "DosenA"), ("NLP", "DosenB"), ("CV", "DosenC"),
    ("IOT", "DosenD"), ("HCI", "DosenE"), ("CyberSec", "DosenF"),
    ("BigData", "DosenA"), ("DL", "DosenB"), ("NoSQL", "DosenC"),
    ("Cloud", "DosenD"), ("UX", "DosenE"), ("SecEng", "DosenF"),
    ("Agile", "DosenA"), ("RL", "DosenB"), ("ETL", "DosenC"),
    ("DevOps", "DosenD"), ("GameDev", "DosenE"), ("Blockchain", "DosenF")
]

rooms = ["R1", "R2", "R3", "R4"]

timeslots = [
    "Senin-08", "Senin-10", "Senin-13",
    "Selasa-08", "Selasa-10", "Selasa-13",
    "Rabu-08", "Rabu-10", "Rabu-13",
    "Kamis-08", "Kamis-10", "Kamis-13"
]

# Parameter Algoritma Genetika Sesuai Soal
POP_SIZE = 60
GENERATIONS = 100
CROSSOVER_RATE = 0.85
MUTATION_RATE = 0.20

# ==========================================
# 2. EVALUASI FITNESS & KONFLIK
# ==========================================
def count_conflicts(individual):
    conflicts = 0
    room_time_slots = {}
    teacher_time_slots = {}
    teacher_days = {}

    for idx, (room, timeslot) in enumerate(individual):
        course, teacher = courses[idx]
        day = timeslot.split("-")[0]

        # Konflik Ruang
        rt_key = (room, timeslot)
        if rt_key in room_time_slots:
            conflicts += 1
        else:
            room_time_slots[rt_key] = True

        # Konflik Dosen-Waktu
        tt_key = (teacher, timeslot)
        if tt_key in teacher_time_slots:
            conflicts += 1
        else:
            teacher_time_slots[tt_key] = True

        # Konflik Dosen-Hari
        td_key = (teacher, day)
        if td_key in teacher_days:
            conflicts += 1
        else:
            teacher_days[td_key] = True

    return conflicts

def calculate_fitness(individual):
    conflicts = count_conflicts(individual)
    fitness = 100.0 / (1.0 + conflicts)
    return fitness, conflicts

# ==========================================
# 3. FUNGSI ALGORITMA GENETIKA
# ==========================================
def create_individual():
    return [(random.choice(rooms), random.choice(timeslots)) for _ in range(len(courses))]

def create_population(pop_size):
    return [create_individual() for _ in range(pop_size)]

def selection(population, fitnesses):
    tournament = random.sample(list(zip(population, fitnesses)), 3)
    tournament.sort(key=lambda x: x[1], reverse=True)
    return tournament[0][0]

def crossover(parent1, parent2):
    if random.random() < CROSSOVER_RATE:
        point = random.randint(1, len(courses) - 1)
        child1 = parent1[:point] + parent2[point:]
        child2 = parent2[:point] + parent1[point:]
        return child1, child2
    return parent1.copy(), parent2.copy()

def mutate(individual):
    for i in range(len(individual)):
        if random.random() < MUTATION_RATE:
            individual[i] = (random.choice(rooms), random.choice(timeslots))
    return individual

# ==========================================
# 4. PROSES EVOLUSI (MAIN LOOP)
# ==========================================
population = create_population(POP_SIZE)

max_fitness_history = []
avg_fitness_history = []

best_global_ind = None
best_global_fit = -1
best_global_conflicts = 999

print(f"=== MEMULAI EVOLUSI PENJADWALAN (NIM: {NIM_RIAN}) ===")

for gen in range(1, GENERATIONS + 1):
    evaluated = [calculate_fitness(ind) for ind in population]
    fitnesses = [f for f, c in evaluated]
    conflicts_list = [c for f, c in evaluated]

    max_fit = max(fitnesses)
    avg_fit = sum(fitnesses) / len(fitnesses)

    max_fitness_history.append(max_fit)
    avg_fitness_history.append(avg_fit)

    best_gen_idx = fitnesses.index(max_fit)
    if max_fit > best_global_fit:
        best_global_fit = max_fit
        best_global_ind = population[best_gen_idx]
        best_global_conflicts = conflicts_list[best_gen_idx]

    print(f"Gen | {gen}: Max Fitness = {max_fit:.2f} | Avg Fitness = {avg_fit:.2f}")

    new_population = []
    sorted_pop = [x for _, x in sorted(zip(fitnesses, population), reverse=True)]
    new_population.extend(sorted_pop[:2]) # Elitisme

    while len(new_population) < POP_SIZE:
        p1 = selection(population, fitnesses)
        p2 = selection(population, fitnesses)
        c1, c2 = crossover(p1, p2)
        new_population.append(mutate(c1))
        if len(new_population) < POP_SIZE:
            new_population.append(mutate(c2))

    population = new_population

# ==========================================
# 5. CETAK KELUARAN JADWAL TERBAIK RIAN
# ==========================================
print(f"\n=== JADWAL TERBAIK (NIM: {NIM_RIAN}) ===")
for idx, (room, timeslot) in enumerate(best_global_ind):
    mk, dosen = courses[idx]
    print(f"MK: {mk:10} | Ruang: {room} | Waktu: {timeslot:9} | Dosen: {dosen}")

print("\n=== HASIL EVALUASI AKHIR ===")
print(f"Fitness Terbaik: {best_global_fit:.2f}")
print(f"Jumlah Konflik : {best_global_conflicts}")

# ==========================================
# 6. VISUALISASI GRAFIK
# ==========================================
plt.figure(figsize=(10, 6))
plt.plot(range(1, GENERATIONS + 1), max_fitness_history, label="Fitness Maksimum", color="black", linewidth=2)
plt.plot(range(1, GENERATIONS + 1), avg_fitness_history, label="Fitness Rata-rata", color="orange", linewidth=1.5)
plt.title(f"Perkembangan Fitness - Penjadwalan Mata Kuliah (NIM: {NIM_RIAN})")
plt.xlabel("Generasi")
plt.ylabel("Fitness")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
# Out:
# === MEMULAI EVOLUSI PENJADWALAN (NIM: 24146049) ===
# Gen | 1: Max Fitness = 8.33 | Avg Fitness = 6.35
# Gen | 2: Max Fitness = 9.09 | Avg Fitness = 6.48
# Gen | 3: Max Fitness = 12.50 | Avg Fitness = 6.82
# Gen | 4: Max Fitness = 14.29 | Avg Fitness = 7.23
# Gen | 5: Max Fitness = 14.29 | Avg Fitness = 7.53
# Gen | 6: Max Fitness = 14.29 | Avg Fitness = 7.56
# Gen | 7: Max Fitness = 14.29 | Avg Fitness = 7.80
# Gen | 8: Max Fitness = 14.29 | Avg Fitness = 7.69
# Gen | 9: Max Fitness = 14.29 | Avg Fitness = 7.72
# Gen | 10: Max Fitness = 14.29 | Avg Fitness = 8.00
# Gen | 11: Max Fitness = 14.29 | Avg Fitness = 8.23
# Gen | 12: Max Fitness = 14.29 | Avg Fitness = 8.02
# Gen | 13: Max Fitness = 14.29 | Avg Fitness = 7.96
# Gen | 14: Max Fitness = 14.29 | Avg Fitness = 7.75
# Gen | 15: Max Fitness = 14.29 | Avg Fitness = 7.73
# Gen | 16: Max Fitness = 14.29 | Avg Fitness = 7.75
# Gen | 17: Max Fitness = 14.29 | Avg Fitness = 7.76
# Gen | 18: Max Fitness = 16.67 | Avg Fitness = 7.64
# Gen | 19: Max Fitness = 16.67 | Avg Fitness = 7.53
# Gen | 20: Max Fitness = 20.00 | Avg Fitness = 7.90
# Gen | 21: Max Fitness = 20.00 | Avg Fitness = 8.42
# Gen | 22: Max Fitness = 20.00 | Avg Fitness = 8.84
# Gen | 23: Max Fitness = 20.00 | Avg Fitness = 8.41
# Gen | 24: Max Fitness = 20.00 | Avg Fitness = 8.97
# Gen | 25: Max Fitness = 20.00 | Avg Fitness = 8.77
# Gen | 26: Max Fitness = 20.00 | Avg Fitness = 8.85
# Gen | 27: Max Fitness = 20.00 | Avg Fitness = 8.68
# Gen | 28: Max Fitness = 20.00 | Avg Fitness = 8.44
# Gen | 29: Max Fitness = 20.00 | Avg Fitness = 8.60
# Gen | 30: Max Fitness = 20.00 | Avg Fitness = 8.95
# Gen | 31: Max Fitness = 20.00 | Avg Fitness = 9.01
# Gen | 32: Max Fitness = 20.00 | Avg Fitness = 8.55
# Gen | 33: Max Fitness = 20.00 | Avg Fitness = 8.64
# Gen | 34: Max Fitness = 20.00 | Avg Fitness = 9.06
# Gen | 35: Max Fitness = 20.00 | Avg Fitness = 8.37
# Gen | 36: Max Fitness = 20.00 | Avg Fitness = 9.14
# Gen | 37: Max Fitness = 20.00 | Avg Fitness = 8.98
# Gen | 38: Max Fitness = 20.00 | Avg Fitness = 9.19
# Gen | 39: Max Fitness = 20.00 | Avg Fitness = 8.75
# Gen | 40: Max Fitness = 20.00 | Avg Fitness = 8.60
# Gen | 41: Max Fitness = 20.00 | Avg Fitness = 8.84
# Gen | 42: Max Fitness = 20.00 | Avg Fitness = 8.47
# Gen | 43: Max Fitness = 20.00 | Avg Fitness = 8.54
# Gen | 44: Max Fitness = 20.00 | Avg Fitness = 8.67
# Gen | 45: Max Fitness = 20.00 | Avg Fitness = 9.46
# Gen | 46: Max Fitness = 20.00 | Avg Fitness = 9.64
# Gen | 47: Max Fitness = 20.00 | Avg Fitness = 9.89
# Gen | 48: Max Fitness = 20.00 | Avg Fitness = 9.71
# Gen | 49: Max Fitness = 20.00 | Avg Fitness = 9.05
# Gen | 50: Max Fitness = 20.00 | Avg Fitness = 8.50
# Gen | 51: Max Fitness = 20.00 | Avg Fitness = 8.77
# Gen | 52: Max Fitness = 20.00 | Avg Fitness = 8.36
# Gen | 53: Max Fitness = 20.00 | Avg Fitness = 8.50
# Gen | 54: Max Fitness = 20.00 | Avg Fitness = 8.57
# Gen | 55: Max Fitness = 20.00 | Avg Fitness = 8.55
# Gen | 56: Max Fitness = 20.00 | Avg Fitness = 8.75
# Gen | 57: Max Fitness = 20.00 | Avg Fitness = 8.58
# Gen | 58: Max Fitness = 20.00 | Avg Fitness = 9.21
# Gen | 59: Max Fitness = 20.00 | Avg Fitness = 8.68
# Gen | 60: Max Fitness = 20.00 | Avg Fitness = 8.44
# Gen | 61: Max Fitness = 20.00 | Avg Fitness = 9.03
# Gen | 62: Max Fitness = 20.00 | Avg Fitness = 9.15
# Gen | 63: Max Fitness = 20.00 | Avg Fitness = 8.91
# Gen | 64: Max Fitness = 20.00 | Avg Fitness = 8.28
# Gen | 65: Max Fitness = 20.00 | Avg Fitness = 8.41
# Gen | 66: Max Fitness = 20.00 | Avg Fitness = 7.99
# Gen | 67: Max Fitness = 20.00 | Avg Fitness = 7.89
# Gen | 68: Max Fitness = 20.00 | Avg Fitness = 8.13
# Gen | 69: Max Fitness = 20.00 | Avg Fitness = 8.26
# Gen | 70: Max Fitness = 20.00 | Avg Fitness = 8.58
# Gen | 71: Max Fitness = 20.00 | Avg Fitness = 8.74
# Gen | 72: Max Fitness = 20.00 | Avg Fitness = 9.31
# Gen | 73: Max Fitness = 20.00 | Avg Fitness = 8.20
# Gen | 74: Max Fitness = 20.00 | Avg Fitness = 8.19
# Gen | 75: Max Fitness = 20.00 | Avg Fitness = 7.90
# Gen | 76: Max Fitness = 20.00 | Avg Fitness = 8.30
# Gen | 77: Max Fitness = 20.00 | Avg Fitness = 8.43
# Gen | 78: Max Fitness = 20.00 | Avg Fitness = 8.13
# Gen | 79: Max Fitness = 20.00 | Avg Fitness = 8.52
# Gen | 80: Max Fitness = 25.00 | Avg Fitness = 8.87
# Gen | 81: Max Fitness = 25.00 | Avg Fitness = 9.44
# Gen | 82: Max Fitness = 25.00 | Avg Fitness = 9.25
# Gen | 83: Max Fitness = 25.00 | Avg Fitness = 9.11
# Gen | 84: Max Fitness = 25.00 | Avg Fitness = 8.96
# Gen | 85: Max Fitness = 25.00 | Avg Fitness = 8.79
# Gen | 86: Max Fitness = 33.33 | Avg Fitness = 9.21
# Gen | 87: Max Fitness = 33.33 | Avg Fitness = 9.04
# Gen | 88: Max Fitness = 33.33 | Avg Fitness = 9.13
# Gen | 89: Max Fitness = 33.33 | Avg Fitness = 8.76
# Gen | 90: Max Fitness = 33.33 | Avg Fitness = 8.80
# Gen | 91: Max Fitness = 33.33 | Avg Fitness = 8.93
# Gen | 92: Max Fitness = 33.33 | Avg Fitness = 9.30
# Gen | 93: Max Fitness = 33.33 | Avg Fitness = 10.19
# Gen | 94: Max Fitness = 33.33 | Avg Fitness = 9.83
# Gen | 95: Max Fitness = 33.33 | Avg Fitness = 9.59
# Gen | 96: Max Fitness = 33.33 | Avg Fitness = 9.14
# Gen | 97: Max Fitness = 33.33 | Avg Fitness = 8.85
# Gen | 98: Max Fitness = 33.33 | Avg Fitness = 8.92
# Gen | 99: Max Fitness = 33.33 | Avg Fitness = 9.06
# Gen | 100: Max Fitness = 33.33 | Avg Fitness = 9.31
#
# === JADWAL TERBAIK (NIM: 24146049) ===
# MK: AI         | Ruang: R1 | Waktu: Rabu-13   | Dosen: DosenA
# MK: ML         | Ruang: R2 | Waktu: Kamis-08  | Dosen: DosenB
# MK: DB         | Ruang: R1 | Waktu: Rabu-10   | Dosen: DosenC
# MK: CN         | Ruang: R1 | Waktu: Rabu-08   | Dosen: DosenD
# MK: SE         | Ruang: R3 | Waktu: Kamis-13  | Dosen: DosenE
# MK: OS         | Ruang: R2 | Waktu: Senin-08  | Dosen: DosenF
# MK: IR         | Ruang: R1 | Waktu: Selasa-08 | Dosen: DosenA
# MK: NLP        | Ruang: R2 | Waktu: Selasa-08 | Dosen: DosenB
# MK: CV         | Ruang: R1 | Waktu: Selasa-10 | Dosen: DosenC
# MK: IOT        | Ruang: R2 | Waktu: Senin-13  | Dosen: DosenD
# MK: HCI        | Ruang: R3 | Waktu: Senin-13  | Dosen: DosenE
# MK: CyberSec   | Ruang: R1 | Waktu: Kamis-13  | Dosen: DosenF
# MK: BigData    | Ruang: R3 | Waktu: Rabu-10   | Dosen: DosenA
# MK: DL         | Ruang: R4 | Waktu: Rabu-08   | Dosen: DosenB
# MK: NoSQL      | Ruang: R3 | Waktu: Kamis-08  | Dosen: DosenC
# MK: Cloud      | Ruang: R2 | Waktu: Selasa-13 | Dosen: DosenD
# MK: UX         | Ruang: R4 | Waktu: Rabu-10   | Dosen: DosenE
# MK: SecEng     | Ruang: R4 | Waktu: Selasa-10 | Dosen: DosenF
# MK: Agile      | Ruang: R1 | Waktu: Senin-10  | Dosen: DosenA
# MK: RL         | Ruang: R4 | Waktu: Kamis-13  | Dosen: DosenB
# MK: ETL        | Ruang: R3 | Waktu: Senin-08  | Dosen: DosenC
# MK: DevOps     | Ruang: R1 | Waktu: Kamis-10  | Dosen: DosenD
# MK: GameDev    | Ruang: R1 | Waktu: Selasa-13 | Dosen: DosenE
# MK: Blockchain | Ruang: R3 | Waktu: Rabu-13   | Dosen: DosenF
#
# === HASIL EVALUASI AKHIR ===
# Fitness Terbaik: 33.33
# Jumlah Konflik : 2
